# %%
from project import Project

# %%
p = Project()

# %%
import pickle

# %%
with open("../../savefile/fitted1.plk","rb") as f:
            p = pickle.load(f)

# %%
p.dataset.data_to_use.ListOfData.values
# Out:
# array([array([  1.,   1.,   1., ..., 130., 130., 131.]),
#        array([  1.,   1.,   1., ..., 122., 123., 123.]),
#        array([  1.,   1.,   1., ..., 126., 127., 127.]),
#        array([  1.,   1.,   1., ..., 159., 159., 159.]),
#        array([  1.,   1.,   1., ..., 143., 143., 143.]),
#        array([  1.,   1.,   1., ..., 131., 131., 131.]),
#        array([  1.,   1.,   1., ..., 131., 131., 131.]),
#        array([  1.,   1.,   1., ..., 127., 127., 127.]),
#        array([  1.,   1.,   1., ..., 127., 127., 127.]),
#        array([  1.,   1.,   1., ..., 135., 135., 135.]),
#        array([  1.,   1.,   1., ..., 127., 127., 127.]),
#        array([  1.,   1.,   1., ..., 123., 123., 123.]),
#        array([  1.,   1.,   1., ..., 123., 123., 123.]),
#        array([  1.,   1.,   1., ..., 123., 123., 123.]),
#        array([  1.,   1.,   1., ..., 123., 123., 123.]),
#        array([  1.,   1.,   1., ..., 131., 131., 131.]),
# ...

# %%
p.dataset.TransferToY()

# %%
p.dataset.data_to_use.ListOfData.values
# Out:
# array([array([0.03030303, 0.03030303, 0.03030303, ..., 3.93939394, 3.93939394,
#        3.96969697]),
#        array([0.03225806, 0.03225806, 0.03225806, ..., 3.93548387, 3.96774194,
#        3.96774194]),
#        array([0.03125, 0.03125, 0.03125, ..., 3.9375 , 3.96875, 3.96875]),
#        array([0.025, 0.025, 0.025, ..., 3.975, 3.975, 3.975]),
#        array([0.02777778, 0.02777778, 0.02777778, ..., 3.97222222, 3.97222222,
#        3.97222222]),
#        array([0.03030303, 0.03030303, 0.03030303, ..., 3.96969697, 3.96969697,
#        3.96969697]),
#        array([0.03030303, 0.03030303, 0.03030303, ..., 3.96969697, 3.96969697,
#        3.96969697]),
#        array([0.03125, 0.03125, 0.03125, ..., 3.96875, 3.96875, 3.96875]),
#        array([0.03125, 0.03125, 0.03125, ..., 3.96875, 3.96875, 3.96875]),
#        array([0.02941176, 0.02941176, 0.02941176, ..., 3.97058824, 3.97058824,
#        3.97058824]),
#        array([0.03125, 0.03125, 0.03125, ..., 3.96875, 3.96875, 3.96875]),
# ...

# %%
p.dataset.TransferToZ()

# %%
p.dataset.data_to_use.ListOfData.values
# Out:
# array([array([-1.73710474, -1.73710474, -1.73710474, ...,  5.26559874,
#         5.26559874,  5.31988327]),
#        array([-1.68909138, -1.68909138, -1.68909138, ...,  5.1235772 ,
#         5.17988024,  5.17988024]),
#        array([-1.66459419, -1.66459419, -1.66459419, ...,  5.04747916,
#         5.10117575,  5.10117575]),
#        array([-1.54818763, -1.54818763, -1.54818763, ...,  4.72395714,
#         4.72395714,  4.72395714]),
#        array([-1.5324707 , -1.5324707 , -1.5324707 , ...,  4.68498186,
#         4.68498186,  4.68498186]),
#        array([-1.66028087, -1.66028087, -1.66028087, ...,  5.08461016,
#         5.08461016,  5.08461016]),
#        array([-1.69124765, -1.69124765, -1.69124765, ...,  5.17944592,
#         5.17944592,  5.17944592]),
#        array([-1.55662888, -1.55662888, -1.55662888, ...,  4.7703143 ,
#         4.7703143 ,  4.7703143 ]),
#        array([-1.67317789, -1.67317789, -1.67317789, ...,  5.12748062,
#         5.12748062,  5.12748062]),
# ...
